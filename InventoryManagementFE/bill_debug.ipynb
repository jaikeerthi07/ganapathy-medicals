# %% [markdown]
# # Inspect Bill.jsx for syntax and React hook usage
#
# Open `src/components/Bill.jsx` and review imports, `useState`/`useEffect` usage, and JSX structure to identify potential syntax issues.

# %% [markdown]
# ## Reproduce the error with npm/yarn
#
# Run the React app build or start command to capture the exact error message and line number.

# %%
from pathlib import Path
path = Path('src/components/Bill.jsx')
text = path.read_text(encoding='utf-8')
print('File exists:', path.exists())
print('Length:', len(text))
print('First 120 chars:\n', text[:120])

# %%
from pathlib import Path
text = Path('src/components/Bill.jsx').read_text(encoding='utf-8')

balances = {'(': 0, ')': 0, '{': 0, '}': 0, '[': 0, ']': 0}
for c in text:
    if c in balances:
        balances[c] += 1

print('Counts:', balances)

lines = text.splitlines()
print('Last 30 lines:')
print('\n'.join(lines[-30:]))
